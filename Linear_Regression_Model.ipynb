# %% [markdown]
# # DATA PREPROCESSING

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings(action='ignore')
data=pd.read_csv('Housing Prices Data.csv')

# %% [markdown]
# # TARGET VARIABLE

# %% [markdown]
# # OUTLIER

# %% [markdown]
# ### Identifying Outlier

# %%
data['Sale Price'].describe()
# Out:
# count    2.160900e+04
# mean     5.401984e+05
# std      3.673890e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: Sale Price, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.style.use('dark_background')

# %%
plt.scatter(x=data['ID'],y=data['Sale Price'])

# %%
import seaborn as sns

# %%
sns.boxplot(x=data['Sale Price'])
# Out:
# <Axes: xlabel='Sale Price'>

# %% [markdown]
# ### Treating Outlier

# %%
q1=data['Sale Price'].quantile(.25)
q3=data['Sale Price'].quantile(.75)
iqr=q3-q1
lower_limit=q1-1.5*iqr
upper_limit=q3+1.5*iqr

# %%
def limit_imputer(value):
    if value>upper_limit:
        return upper_limit
    elif value<lower_limit:
        return lower_limit
    else:
        return value

# %%
data['Sale Price']=data['Sale Price'].apply(limit_imputer)

# %% [markdown]
# ### Results

# %%
data['Sale Price'].describe()
#here can we see that our mean value is reduced but it is not closer to .50 because the data is not skewed properly
# Out:
# count    2.160900e+04
# mean     5.116186e+05
# std      2.500620e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      1.129575e+06
# Name: Sale Price, dtype: float64

# %%
plt.scatter(x=data['ID'],y=data['Sale Price'])

# %%
sns.boxplot(x=data['Sale Price'])
# Out:
# <Axes: xlabel='Sale Price'>

# %% [markdown]
# # MISSING VALUES

# %% [markdown]
# ### Identifying Missing Values

# %%
data['Sale Price'].describe()
# Out:
# count    2.160900e+04
# mean     5.116186e+05
# std      2.500620e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      1.129575e+06
# Name: Sale Price, dtype: float64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21613 non-null  int64
#  1   Date House was Sold                        21613 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21613 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21604 non-null  float64
#  6   Lot Area (in Sqft)                         21604 non-null  float64
#  7   No of Floors                               21613 non-null  float64
#  8   Waterfront View                            21613 non-null  object
#  9   No of Times Visited                        21613 non-null  object
#  10  Condition of the House                     21613 non-null  object
#  11  Overall Grade                              21613 non-null  int64
#  12  Area of the House from Basement (in Sqft)  21610 non-null  float64
#  13  Basement Area (in Sqft)                    21613 non-null  int64
#  14  Age of House (in Years)                    21613 non-null  int64
#  15  Renovated Year                             21613 non-null  int64
#  16  Zipcode                                    21612 non-null  float64
#  17  Latitude                                   21612 non-null  float64
#  18  Longitude                                  21612 non-null  float64
#  19  Living Area after Renovation (in Sqft)     21612 non-null  float64
#  20  Lot Area after Renovation (in Sqft)        21613 non-null  int64
# dtypes: float64(10), int64(7), object(4)
# memory usage: 3.5+ MB

# %% [markdown]
# ### Treating Missing Value

# %%
data.dropna(inplace=True,axis=0,subset=['Sale Price'])

# %% [markdown]
# ### Results

# %%
data['Sale Price'].describe()
# Out:
# count    2.160900e+04
# mean     5.116186e+05
# std      2.500620e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      1.129575e+06
# Name: Sale Price, dtype: float64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21609 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21609 non-null  int64
#  1   Date House was Sold                        21609 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21609 non-null  int64
#  4   No of Bathrooms                            21605 non-null  float64
#  5   Flat Area (in Sqft)                        21600 non-null  float64
#  6   Lot Area (in Sqft)                         21600 non-null  float64
#  7   No of Floors                               21609 non-null  float64
#  8   Waterfront View                            21609 non-null  object
#  9   No of Times Visited                        21609 non-null  object
#  10  Condition of the House                     21609 non-null  object
#  11  Overall Grade                              21609 non-null  int64
#  12  Area of the House from Basement (in Sqft)  21606 non-null  float64
#  13  Basement Area (in Sqft)                    21609 non-null  int64
#  14  Age of House (in Years)                    21609 non-null  int64
#  15  Renovated Year                             21609 non-null  int64
#  16  Zipcode                                    21608 non-null  float64
#  17  Latitude                                   21608 non-null  float64
#  18  Longitude                                  21608 non-null  float64
#  19  Living Area after Renovation (in Sqft)     21608 non-null  float64
#  20  Lot Area after Renovation (in Sqft)        21609 non-null  int64
# dtypes: float64(10), int64(7), object(4)
# memory usage: 3.6+ MB

# %%
plt.hist(data['Sale Price'],bins=10,color='green')
plt.ylabel('Sale Price')
plt.xlabel('Intervals')
plt.title('Histogram of Selling Price')
#we get know that the data is skewed against lower value
# Out:
# Text(0.5, 1.0, 'Histogram of Selling Price')

# %% [markdown]
# # INDEPENDENT VARIABLE

# %% [markdown]
# # MISSING VALUES

# %% [markdown]
# ### Identifying Missing Values

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21609 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21609 non-null  int64
#  1   Date House was Sold                        21609 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21609 non-null  int64
#  4   No of Bathrooms                            21605 non-null  float64
#  5   Flat Area (in Sqft)                        21600 non-null  float64
#  6   Lot Area (in Sqft)                         21600 non-null  float64
#  7   No of Floors                               21609 non-null  float64
#  8   Waterfront View                            21609 non-null  object
#  9   No of Times Visited                        21609 non-null  object
#  10  Condition of the House                     21609 non-null  object
#  11  Overall Grade                              21609 non-null  int64
#  12  Area of the House from Basement (in Sqft)  21606 non-null  float64
#  13  Basement Area (in Sqft)                    21609 non-null  int64
#  14  Age of House (in Years)                    21609 non-null  int64
#  15  Renovated Year                             21609 non-null  int64
#  16  Zipcode                                    21608 non-null  float64
#  17  Latitude                                   21608 non-null  float64
#  18  Longitude                                  21608 non-null  float64
#  19  Living Area after Renovation (in Sqft)     21608 non-null  float64
#  20  Lot Area after Renovation (in Sqft)        21609 non-null  int64
# dtypes: float64(10), int64(7), object(4)
# memory usage: 3.6+ MB

# %% [markdown]
# ### Treating Missing Value

# %% [markdown]
# ### For Quantitative column

# %%
quantitative_column=['No of Bathrooms','Flat Area (in Sqft)','Lot Area (in Sqft)','Area of the House from Basement (in Sqft)','Latitude','Longitude','Living Area after Renovation (in Sqft)']

# %%
data['No of Bathrooms'].isnull().sum()
# Out:
# 4

# %%
from sklearn.impute import SimpleImputer

# %%
impute=SimpleImputer(missing_values=np.nan,strategy='median')

# %%
data[quantitative_column]=impute.fit_transform(data[quantitative_column])

# %% [markdown]
# ### Result

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21609 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21609 non-null  int64
#  1   Date House was Sold                        21609 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21609 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21609 non-null  float64
#  6   Lot Area (in Sqft)                         21609 non-null  float64
#  7   No of Floors                               21609 non-null  float64
#  8   Waterfront View                            21609 non-null  object
#  9   No of Times Visited                        21609 non-null  object
#  10  Condition of the House                     21609 non-null  object
#  11  Overall Grade                              21609 non-null  int64
#  12  Area of the House from Basement (in Sqft)  21609 non-null  float64
#  13  Basement Area (in Sqft)                    21609 non-null  int64
#  14  Age of House (in Years)                    21609 non-null  int64
#  15  Renovated Year                             21609 non-null  int64
#  16  Zipcode                                    21608 non-null  float64
#  17  Latitude                                   21609 non-null  float64
#  18  Longitude                                  21609 non-null  float64
#  19  Living Area after Renovation (in Sqft)     21609 non-null  float64
#  20  Lot Area after Renovation (in Sqft)        21609 non-null  int64
# dtypes: float64(10), int64(7), object(4)
# memory usage: 3.6+ MB

# %% [markdown]
# ### For Categorical column

# %%
impute=SimpleImputer(missing_values=np.nan,strategy='most_frequent')

# %%
#data['Zipcode']=impute.fit_transform(data['Zipcode'])
#it will show an error that zipcode is a 1d array 
#it may be because of not using pandas dataframe,maybe pandas series is used

# %%
print(data['Zipcode'])
# Out:
# <bound method Series.unique of 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 21608    False
# 21609    False
# 21610    False
# 21611    False
# 21612    False
# Name: Zipcode, Length: 21609, dtype: bool>

# %%
column=data['Zipcode'].values.reshape(-1,1)
column.shape
impute=SimpleImputer(missing_values=np.nan,strategy='most_frequent')
data['Zipcode']=impute.fit_transform(column)
# Out:
# (21609, 1)

# %% [markdown]
# ### Result

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21609 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21609 non-null  int64
#  1   Date House was Sold                        21609 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21609 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21609 non-null  float64
#  6   Lot Area (in Sqft)                         21609 non-null  float64
#  7   No of Floors                               21609 non-null  float64
#  8   Waterfront View                            21609 non-null  object
#  9   No of Times Visited                        21609 non-null  object
#  10  Condition of the House                     21609 non-null  object
#  11  Overall Grade                              21609 non-null  int64
#  12  Area of the House from Basement (in Sqft)  21609 non-null  float64
#  13  Basement Area (in Sqft)                    21609 non-null  int64
#  14  Age of House (in Years)                    21609 non-null  int64
#  15  Renovated Year                             21609 non-null  int64
#  16  Zipcode                                    21609 non-null  float64
#  17  Latitude                                   21609 non-null  float64
#  18  Longitude                                  21609 non-null  float64
#  19  Living Area after Renovation (in Sqft)     21609 non-null  float64
#  20  Lot Area after Renovation (in Sqft)        21609 non-null  int64
# dtypes: float64(10), int64(7), object(4)
# memory usage: 3.6+ MB

# %% [markdown]
# # VARIABLE TRANSFORMATION

# %% [markdown]
# ### To make variable more usefull

# %% [markdown]
# ### Zipcode

# %%
data['Zipcode']=data['Zipcode'].astype(object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21609 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21609 non-null  int64
#  1   Date House was Sold                        21609 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21609 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21609 non-null  float64
#  6   Lot Area (in Sqft)                         21609 non-null  float64
#  7   No of Floors                               21609 non-null  float64
#  8   Waterfront View                            21609 non-null  object
#  9   No of Times Visited                        21609 non-null  object
#  10  Condition of the House                     21609 non-null  object
#  11  Overall Grade                              21609 non-null  int64
#  12  Area of the House from Basement (in Sqft)  21609 non-null  float64
#  13  Basement Area (in Sqft)                    21609 non-null  int64
#  14  Age of House (in Years)                    21609 non-null  int64
#  15  Renovated Year                             21609 non-null  int64
#  16  Zipcode                                    21609 non-null  object
#  17  Latitude                                   21609 non-null  float64
#  18  Longitude                                  21609 non-null  float64
#  19  Living Area after Renovation (in Sqft)     21609 non-null  float64
#  20  Lot Area after Renovation (in Sqft)        21609 non-null  int64
# dtypes: float64(9), int64(7), object(5)
# memory usage: 3.6+ MB

# %% [markdown]
# ### No of Times Visited

# %%
data['No of Times Visited'].unique()
# Out:
# array(['Zero', 'Thrice', 'Four', 'Twice', 'Once'], dtype=object)

# %%
mapping = {'Zero':'0',
           'Once': '1',
           'Twice':'2',
           'Thrice':'3',
           'Four':'4'}
data['No of Times Visited']=data['No of Times Visited'].map(mapping)

# %%
data['No of Times Visited'].unique()
# Out:
# array(['0', '3', '4', '2', '1'], dtype=object)

# %%
data['No of Times Visited']=data['No of Times Visited'].astype('int64')

# %%
data['No of Times Visited'].dtype
# Out:
# dtype('int64')

# %%
np.unique(data['No of Times Visited'])
# Out:
# array([0, 1, 2, 3, 4], dtype=int64)

# %% [markdown]
# ### Derive new variable from existing variables to make it more usefull

# %%
data.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520           14-Oct-17    221900.0               3
# 1  6414100192           14-Dec-17    538000.0               3
# 2  5631500400           15-Feb-16    180000.0               2
# 3  2487200875           14-Dec-17    604000.0               4
# 4  1954400510           15-Feb-16    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View  No of Times Visited  ... Overall Grade  \
# 0              No                    0  ...             7
# 1              No                    0  ...             7
# 2              No                    0  ...             6
# 3              No                    0  ...             7
# 4              No                    0  ...             8
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  \
# 0                                     1180.0                        0
# 1                                     2170.0                      400
# 2                                      770.0                        0
# 3                                     1050.0                      910
# 4                                     1680.0                        0
#
#    Age of House (in Years)  Renovated Year  Zipcode Latitude  Longitude  \
# 0                       63               0  98178.0  47.5112   -122.257
# 1                       67            1991  98125.0  47.7210   -122.319
# 2                       85               0  98028.0  47.7379   -122.233
# 3                       53               0  98136.0  47.5208   -122.393
# 4                       31               0  98074.0  47.6168   -122.045
#
#    Living Area after Renovation (in Sqft)  Lot Area after Renovation (in Sqft)
# 0                                  1340.0                                 5650
# 1                                  1690.0                                 7639
# 2                                  2720.0                                 8062
# 3                                  1360.0                                 5000
# 4                                  1800.0                                 7503
#
# [5 rows x 21 columns]

# %%
data['Ever Renovated']=np.where(data['Renovated Year']==0,'No','Yes')

# %%
data.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520           14-Oct-17    221900.0               3
# 1  6414100192           14-Dec-17    538000.0               3
# 2  5631500400           15-Feb-16    180000.0               2
# 3  2487200875           14-Dec-17    604000.0               4
# 4  1954400510           15-Feb-16    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View  No of Times Visited  ...  \
# 0              No                    0  ...
# 1              No                    0  ...
# 2              No                    0  ...
# 3              No                    0  ...
# 4              No                    0  ...
#
#   Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  \
# 0                                    1180.0                        0
# 1                                    2170.0                      400
# 2                                     770.0                        0
# 3                                    1050.0                      910
# 4                                    1680.0                        0
#
#    Age of House (in Years)  Renovated Year  Zipcode  Latitude Longitude  \
# 0                       63               0  98178.0   47.5112  -122.257
# 1                       67            1991  98125.0   47.7210  -122.319
# 2                       85               0  98028.0   47.7379  -122.233
# 3                       53               0  98136.0   47.5208  -122.393
# 4                       31               0  98074.0   47.6168  -122.045
#
#    Living Area after Renovation (in Sqft)  \
# 0                                  1340.0
# 1                                  1690.0
# 2                                  2720.0
# 3                                  1360.0
# 4                                  1800.0
#
#    Lot Area after Renovation (in Sqft)  Ever Renovated
# 0                                 5650              No
# 1                                 7639             Yes
# 2                                 8062              No
# 3                                 5000              No
# 4                                 7503              No
#
# [5 rows x 22 columns]

# %%
data['Purchase Year']=pd.DatetimeIndex(data['Date House was Sold']).year

# %%
data.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520           14-Oct-17    221900.0               3
# 1  6414100192           14-Dec-17    538000.0               3
# 2  5631500400           15-Feb-16    180000.0               2
# 3  2487200875           14-Dec-17    604000.0               4
# 4  1954400510           15-Feb-16    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View  No of Times Visited  ... Basement Area (in Sqft)  \
# 0              No                    0  ...                       0
# 1              No                    0  ...                     400
# 2              No                    0  ...                       0
# 3              No                    0  ...                     910
# 4              No                    0  ...                       0
#
#    Age of House (in Years)  Renovated Year  Zipcode  Latitude  Longitude  \
# 0                       63               0  98178.0   47.5112   -122.257
# 1                       67            1991  98125.0   47.7210   -122.319
# 2                       85               0  98028.0   47.7379   -122.233
# 3                       53               0  98136.0   47.5208   -122.393
# 4                       31               0  98074.0   47.6168   -122.045
#
#   Living Area after Renovation (in Sqft)  Lot Area after Renovation (in Sqft)  \
# 0                                 1340.0                                 5650
# 1                                 1690.0                                 7639
# 2                                 2720.0                                 8062
# 3                                 1360.0                                 5000
# 4                                 1800.0                                 7503
#
#    Ever Renovated  Purchase Year
# 0              No           2017
# 1             Yes           2017
# 2              No           2016
# 3              No           2017
# 4              No           2016
#
# [5 rows x 23 columns]

# %%
data['Years Since Renovation']=np.where(data['Ever Renovated']=='Yes',abs(data['Purchase Year']-data['Renovated Year']),0)

# %%
data.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520           14-Oct-17    221900.0               3
# 1  6414100192           14-Dec-17    538000.0               3
# 2  5631500400           15-Feb-16    180000.0               2
# 3  2487200875           14-Dec-17    604000.0               4
# 4  1954400510           15-Feb-16    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View  No of Times Visited  ... Age of House (in Years)  \
# 0              No                    0  ...                      63
# 1              No                    0  ...                      67
# 2              No                    0  ...                      85
# 3              No                    0  ...                      53
# 4              No                    0  ...                      31
#
#    Renovated Year  Zipcode  Latitude  Longitude  \
# 0               0  98178.0   47.5112   -122.257
# 1            1991  98125.0   47.7210   -122.319
# 2               0  98028.0   47.7379   -122.233
# 3               0  98136.0   47.5208   -122.393
# 4               0  98074.0   47.6168   -122.045
#
#    Living Area after Renovation (in Sqft) Lot Area after Renovation (in Sqft)  \
# 0                                  1340.0                                5650
# 1                                  1690.0                                7639
# 2                                  2720.0                                8062
# 3                                  1360.0                                5000
# 4                                  1800.0                                7503
#
#    Ever Renovated  Purchase Year  Years Since Renovation
# 0              No           2017                       0
# 1             Yes           2017                      26
# 2              No           2016                       0
# 3              No           2017                       0
# 4              No           2016                       0
#
# [5 rows x 24 columns]

# %%
data.drop(columns=['ID','Purchase Year','Date House was Sold','Renovated Year'],inplace=True)

# %%
data.head()
# Out:
#    Sale Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0    221900.0               3             1.00               1180.0
# 1    538000.0               3             2.25               2570.0
# 2    180000.0               2             1.00                770.0
# 3    604000.0               4             3.00               1960.0
# 4    510000.0               3             2.00               1680.0
#
#    Lot Area (in Sqft)  No of Floors Waterfront View  No of Times Visited  \
# 0              5650.0           1.0              No                    0
# 1              7242.0           2.0              No                    0
# 2             10000.0           1.0              No                    0
# 3              5000.0           1.0              No                    0
# 4              8080.0           1.0              No                    0
#
#   Condition of the House  Overall Grade  \
# 0                   Fair              7
# 1                   Fair              7
# 2                   Fair              6
# 3              Excellent              7
# 4                   Fair              8
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  \
# 0                                     1180.0                        0
# 1                                     2170.0                      400
# 2                                      770.0                        0
# 3                                     1050.0                      910
# 4                                     1680.0                        0
#
#    Age of House (in Years)  Zipcode  Latitude  Longitude  \
# 0                       63  98178.0   47.5112   -122.257
# 1                       67  98125.0   47.7210   -122.319
# 2                       85  98028.0   47.7379   -122.233
# 3                       53  98136.0   47.5208   -122.393
# 4                       31  98074.0   47.6168   -122.045
#
#    Living Area after Renovation (in Sqft)  \
# 0                                  1340.0
# 1                                  1690.0
# 2                                  2720.0
# 3                                  1360.0
# 4                                  1800.0
#
#    Lot Area after Renovation (in Sqft) Ever Renovated  Years Since Renovation
# 0                                 5650             No                       0
# 1                                 7639            Yes                      26
# 2                                 8062             No                       0
# 3                                 5000             No                       0
# 4                                 7503             No                       0

# %% [markdown]
# # CORRELATION

# %% [markdown]
# ### Among Categorical Variable

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21609 entries, 0 to 21612
# Data columns (total 20 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Sale Price                                 21609 non-null  float64
#  1   No of Bedrooms                             21609 non-null  int64
#  2   No of Bathrooms                            21609 non-null  float64
#  3   Flat Area (in Sqft)                        21609 non-null  float64
#  4   Lot Area (in Sqft)                         21609 non-null  float64
#  5   No of Floors                               21609 non-null  float64
#  6   Waterfront View                            21609 non-null  object
#  7   No of Times Visited                        21609 non-null  int64
#  8   Condition of the House                     21609 non-null  object
#  9   Overall Grade                              21609 non-null  int64
#  10  Area of the House from Basement (in Sqft)  21609 non-null  float64
#  11  Basement Area (in Sqft)                    21609 non-null  int64
#  12  Age of House (in Years)                    21609 non-null  int64
#  13  Zipcode                                    21609 non-null  object
#  14  Latitude                                   21609 non-null  float64
#  15  Longitude                                  21609 non-null  float64
#  16  Living Area after Renovation (in Sqft)     21609 non-null  float64
#  17  Lot Area after Renovation (in Sqft)        21609 non-null  int64
#  18  Ever Renovated                             21609 non-null  object
#  19  Years Since Renovation                     21609 non-null  int64
# dtypes: float64(9), int64(7), object(4)
# memory usage: 3.5+ MB

# %%
data['Condition of the House'].value_counts()
# Out:
# Condition of the House
# Fair         14028
# Good          5678
# Excellent     1701
# Okay           172
# Bad             30
# Name: count, dtype: int64

# %%
data.groupby('Condition of the House')['Sale Price'].mean().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Condition of the House'>

# %%
data.groupby('Waterfront View')['Sale Price'].mean().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Waterfront View'>

# %%
data.groupby('Ever Renovated')['Sale Price'].mean().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Ever Renovated'>

# %%
data.groupby('Zipcode')['Sale Price'].mean().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Zipcode'>

# %% [markdown]
# # ANOVA

# %%
from statsmodels.formula.api import ols
import statsmodels.api as sm

# %%
data=data.rename(columns={'Sale Price':'Sale_Price'})
data=data.rename(columns={'Waterfront View':'Waterfront_View'})
data=data.rename(columns={'Condition of the House':'Condition_of_the_House'})
data=data.rename(columns={'Ever Renovated':'Ever_Renovated'})

# %%
mod=ols('Sale_Price ~ Condition_of_the_House',data=data).fit()
Anova_Table=sm.stats.anova_lm(mod,typ=2)
print(Anova_Table)
#F value is large and p value is less than 0.05 so this mean diffrence is avg mean values is genuine
#means categorical variable do have an impact on target variable
# Out:
#                               sum_sq       df         F        PR(>F)
# Condition_of_the_House  1.441831e+13      4.0  58.25563  5.447605e-49
# Residual                1.336752e+15  21604.0       NaN           NaN

# %%
mod=ols('Sale_Price ~ Waterfront_View',data=data).fit()
Anova_Table=sm.stats.anova_lm(mod,typ=2)
print(Anova_Table)
# Out:
#                        sum_sq       df           F         PR(>F)
# Waterfront_View  3.283737e+13      1.0  538.192683  1.275558e-117
# Residual         1.318333e+15  21607.0         NaN            NaN

# %%
mod=ols('Sale_Price ~ Ever_Renovated',data=data).fit()
Anova_Table=sm.stats.anova_lm(mod,typ=2)
print(Anova_Table)
# Out:
#                       sum_sq       df           F        PR(>F)
# Ever_Renovated  1.998463e+13      1.0  324.378469  5.419055e-72
# Residual        1.331185e+15  21607.0         NaN           NaN

# %%
mod=ols('Sale_Price ~ Zipcode',data=data).fit()
Anova_Table=sm.stats.anova_lm(mod,typ=2)
print(Anova_Table)
# Out:
#                 sum_sq       df           F  PR(>F)
# Zipcode   6.859657e+14     69.0  321.902033     0.0
# Residual  6.652044e+14  21539.0         NaN     NaN

# %% [markdown]
# # DUMMY VARIABLES

# %%
#used to convert categorical variable to numerical variable to use in regression

# %%
data=pd.get_dummies(data,columns=['Condition_of_the_House','Waterfront_View','Ever_Renovated'],drop_first=True)

# %%
data.head()
# Out:
#    Sale_Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0    221900.0               3             1.00               1180.0
# 1    538000.0               3             2.25               2570.0
# 2    180000.0               2             1.00                770.0
# 3    604000.0               4             3.00               1960.0
# 4    510000.0               3             2.00               1680.0
#
#    Lot Area (in Sqft)  No of Floors  No of Times Visited  Overall Grade  \
# 0              5650.0           1.0                    0              7
# 1              7242.0           2.0                    0              7
# 2             10000.0           1.0                    0              6
# 3              5000.0           1.0                    0              7
# 4              8080.0           1.0                    0              8
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  ...  \
# 0                                     1180.0                        0  ...
# 1                                     2170.0                      400  ...
# 2                                      770.0                        0  ...
# 3                                     1050.0                      910  ...
# 4                                     1680.0                        0  ...
#
#    Longitude Living Area after Renovation (in Sqft)  \
# 0   -122.257                                 1340.0
# 1   -122.319                                 1690.0
# 2   -122.233                                 2720.0
# 3   -122.393                                 1360.0
# 4   -122.045                                 1800.0
#
#    Lot Area after Renovation (in Sqft)  Years Since Renovation  \
# 0                                 5650                       0
# 1                                 7639                      26
# 2                                 8062                       0
# 3                                 5000                       0
# 4                                 7503                       0
#
#    Condition_of_the_House_Excellent  Condition_of_the_House_Fair  \
# 0                             False                         True
# 1                             False                         True
# 2                             False                         True
# 3                              True                        False
# 4                             False                         True
#
#    Condition_of_the_House_Good  Condition_of_the_House_Okay  \
# 0                        False                        False
# 1                        False                        False
# 2                        False                        False
# 3                        False                        False
# 4                        False                        False
#
#    Waterfront_View_Yes  Ever_Renovated_Yes
# 0                False               False
# 1                False                True
# 2                False               False
# 3                False               False
# 4                False               False
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Binning

# %%
#used for variables having more than 20 values in it like zipcode

# %%
Zip_table=data.groupby('Zipcode').agg({'Sale_Price':'mean'}).sort_values('Sale_Price',ascending=True)

# %%
Zip_table.head()
# Out:
#             Sale_Price
# Zipcode
# 98002.0  234284.035176
# 98168.0  240328.371747
# 98032.0  251296.240000
# 98001.0  280804.690608
# 98148.0  284908.596491

# %%
Zip_table['Zipcode_Group']=pd.cut(Zip_table['Sale_Price'],bins=10,labels=['Zipcode_Group0',
                                                         'Zipcode_Group1',
                                                         'Zipcode_Group2',
                                                         'Zipcode_Group3',
                                                         'Zipcode_Group4',
                                                         'Zipcode_Group5',
                                                         'Zipcode_Group6',
                                                         'Zipcode_Group7',
                                                         'Zipcode_Group8',
                                                         'Zipcode_Group9'],
                                                         include_lowest=True)
Zip_table=Zip_table.drop(columns="Sale_Price")

# %%
Zip_table
# Out:
#           Zipcode_Group
# Zipcode
# 98002.0  Zipcode_Group0
# 98168.0  Zipcode_Group0
# 98032.0  Zipcode_Group0
# 98001.0  Zipcode_Group0
# 98148.0  Zipcode_Group0
# ...                 ...
# 98109.0  Zipcode_Group6
# 98112.0  Zipcode_Group7
# 98040.0  Zipcode_Group8
# 98004.0  Zipcode_Group8
# 98039.0  Zipcode_Group9
#
# [70 rows x 1 columns]

# %%
data=pd.merge(data,Zip_table,left_on='Zipcode',how='left',right_index=True)

# %%
data.head()
# Out:
#    Sale_Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0    221900.0               3             1.00               1180.0
# 1    538000.0               3             2.25               2570.0
# 2    180000.0               2             1.00                770.0
# 3    604000.0               4             3.00               1960.0
# 4    510000.0               3             2.00               1680.0
#
#    Lot Area (in Sqft)  No of Floors  No of Times Visited  Overall Grade  \
# 0              5650.0           1.0                    0              7
# 1              7242.0           2.0                    0              7
# 2             10000.0           1.0                    0              6
# 3              5000.0           1.0                    0              7
# 4              8080.0           1.0                    0              8
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  ...  \
# 0                                     1180.0                        0  ...
# 1                                     2170.0                      400  ...
# 2                                      770.0                        0  ...
# 3                                     1050.0                      910  ...
# 4                                     1680.0                        0  ...
#
#    Living Area after Renovation (in Sqft) Lot Area after Renovation (in Sqft)  \
# 0                                  1340.0                                5650
# 1                                  1690.0                                7639
# 2                                  2720.0                                8062
# 3                                  1360.0                                5000
# 4                                  1800.0                                7503
#
#    Years Since Renovation  Condition_of_the_House_Excellent  \
# 0                       0                             False
# 1                      26                             False
# 2                       0                             False
# 3                       0                              True
# 4                       0                             False
#
#    Condition_of_the_House_Fair  Condition_of_the_House_Good  \
# 0                         True                        False
# 1                         True                        False
# 2                         True                        False
# 3                        False                        False
# 4                         True                        False
#
#    Condition_of_the_House_Okay  Waterfront_View_Yes  Ever_Renovated_Yes  \
# 0                        False                False               False
# 1                        False                False                True
# 2                        False                False               False
# 3                        False                False               False
# 4                        False                False               False
#
#     Zipcode_Group
# 0  Zipcode_Group0
# 1  Zipcode_Group2
# 2  Zipcode_Group2
# 3  Zipcode_Group3
# 4  Zipcode_Group4
#
# [5 rows x 24 columns]

# %%
data=pd.get_dummies(data,columns=['Zipcode_Group'],drop_first=True)

# %%
data.drop(columns='Zipcode',inplace=True)

# %%
data.head()
# Out:
#    Sale_Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0    221900.0               3             1.00               1180.0
# 1    538000.0               3             2.25               2570.0
# 2    180000.0               2             1.00                770.0
# 3    604000.0               4             3.00               1960.0
# 4    510000.0               3             2.00               1680.0
#
#    Lot Area (in Sqft)  No of Floors  No of Times Visited  Overall Grade  \
# 0              5650.0           1.0                    0              7
# 1              7242.0           2.0                    0              7
# 2             10000.0           1.0                    0              6
# 3              5000.0           1.0                    0              7
# 4              8080.0           1.0                    0              8
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  ...  \
# 0                                     1180.0                        0  ...
# 1                                     2170.0                      400  ...
# 2                                      770.0                        0  ...
# 3                                     1050.0                      910  ...
# 4                                     1680.0                        0  ...
#
#    Ever_Renovated_Yes  Zipcode_Group_Zipcode_Group1  \
# 0               False                         False
# 1                True                         False
# 2               False                         False
# 3               False                         False
# 4               False                         False
#
#    Zipcode_Group_Zipcode_Group2  Zipcode_Group_Zipcode_Group3  \
# 0                         False                         False
# 1                          True                         False
# 2                          True                         False
# 3                         False                          True
# 4                         False                         False
#
#    Zipcode_Group_Zipcode_Group4  Zipcode_Group_Zipcode_Group5  \
# 0                         False                         False
# 1                         False                         False
# 2                         False                         False
# 3                         False                         False
# 4                          True                         False
#
#    Zipcode_Group_Zipcode_Group6  Zipcode_Group_Zipcode_Group7  \
# 0                         False                         False
# 1                         False                         False
# 2                         False                         False
# 3                         False                         False
# 4                         False                         False
#
#    Zipcode_Group_Zipcode_Group8  Zipcode_Group_Zipcode_Group9
# 0                         False                         False
# 1                         False                         False
# 2                         False                         False
# 3                         False                         False
# 4                         False                         False
#
# [5 rows x 31 columns]

# %%
#Just tranforming variable to int and float from bool for applying in linear regression model
data[['Condition_of_the_House_Excellent','Condition_of_the_House_Fair','Condition_of_the_House_Good','Condition_of_the_House_Okay','Waterfront_View_Yes','Ever_Renovated_Yes','Zipcode_Group_Zipcode_Group1','Zipcode_Group_Zipcode_Group2','Zipcode_Group_Zipcode_Group3','Zipcode_Group_Zipcode_Group4','Zipcode_Group_Zipcode_Group5','Zipcode_Group_Zipcode_Group6','Zipcode_Group_Zipcode_Group7','Zipcode_Group_Zipcode_Group8','Zipcode_Group_Zipcode_Group9']]=data[['Condition_of_the_House_Excellent','Condition_of_the_House_Fair','Condition_of_the_House_Good','Condition_of_the_House_Okay','Waterfront_View_Yes','Ever_Renovated_Yes','Zipcode_Group_Zipcode_Group1','Zipcode_Group_Zipcode_Group2','Zipcode_Group_Zipcode_Group3','Zipcode_Group_Zipcode_Group4','Zipcode_Group_Zipcode_Group5','Zipcode_Group_Zipcode_Group6','Zipcode_Group_Zipcode_Group7','Zipcode_Group_Zipcode_Group8','Zipcode_Group_Zipcode_Group9']].astype('int64')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21609 entries, 0 to 21612
# Data columns (total 31 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Sale_Price                                 21609 non-null  float64
#  1   No of Bedrooms                             21609 non-null  int64
#  2   No of Bathrooms                            21609 non-null  float64
#  3   Flat Area (in Sqft)                        21609 non-null  float64
#  4   Lot Area (in Sqft)                         21609 non-null  float64
#  5   No of Floors                               21609 non-null  float64
#  6   No of Times Visited                        21609 non-null  int64
#  7   Overall Grade                              21609 non-null  int64
#  8   Area of the House from Basement (in Sqft)  21609 non-null  float64
#  9   Basement Area (in Sqft)                    21609 non-null  int64
#  10  Age of House (in Years)                    21609 non-null  int64
#  11  Latitude                                   21609 non-null  float64
#  12  Longitude                                  21609 non-null  float64
#  13  Living Area after Renovation (in Sqft)     21609 non-null  float64
#  14  Lot Area after Renovation (in Sqft)        21609 non-null  int64
#  15  Years Since Renovation                     21609 non-null  int64
#  16  Condition_of_the_House_Excellent           21609 non-null  int64
#  17  Condition_of_the_House_Fair                21609 non-null  int64
#  18  Condition_of_the_House_Good                21609 non-null  int64
#  19  Condition_of_the_House_Okay                21609 non-null  int64
#  20  Waterfront_View_Yes                        21609 non-null  int64
#  21  Ever_Renovated_Yes                         21609 non-null  int64
#  22  Zipcode_Group_Zipcode_Group1               21609 non-null  int64
#  23  Zipcode_Group_Zipcode_Group2               21609 non-null  int64
#  24  Zipcode_Group_Zipcode_Group3               21609 non-null  int64
#  25  Zipcode_Group_Zipcode_Group4               21609 non-null  int64
#  26  Zipcode_Group_Zipcode_Group5               21609 non-null  int64
#  27  Zipcode_Group_Zipcode_Group6               21609 non-null  int64
#  28  Zipcode_Group_Zipcode_Group7               21609 non-null  int64
#  29  Zipcode_Group_Zipcode_Group8               21609 non-null  int64
#  30  Zipcode_Group_Zipcode_Group9               21609 non-null  int64
# dtypes: float64(9), int64(22)
# memory usage: 5.3 MB

# %% [markdown]
# # LINEAR REGRESSION

# %% [markdown]
# # SCALING

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
Y=data['Sale_Price']
X=scaler.fit_transform(data.drop(columns='Sale_Price'))
X=pd.DataFrame(data=X,columns=data.drop(columns='Sale_Price').columns)
X.head()
# Out:
#    No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  \
# 0       -0.398724        -1.447526            -0.979905           -0.228291
# 1       -0.398724         0.175684             0.533718           -0.189858
# 2       -1.474115        -1.447526            -1.426369           -0.123276
# 3        0.676667         1.149611            -0.130534           -0.243983
# 4       -0.398724        -0.148958            -0.435436           -0.169628
#
#    No of Floors  No of Times Visited  Overall Grade  \
# 0     -0.915389             -0.30579      -0.563993
# 1      0.936817             -0.30579      -0.563993
# 2     -0.915389             -0.30579      -1.468566
# 3     -0.915389             -0.30579      -0.563993
# 4     -0.915389             -0.30579       0.340581
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  \
# 0                                  -0.734722                -0.658697
# 1                                   0.460990                 0.245134
# 2                                  -1.229916                -0.658697
# 3                                  -0.891735                 1.397518
# 4                                  -0.130827                -0.658697
#
#    Age of House (in Years)  ...  Ever_Renovated_Yes  \
# 0                 0.544734  ...           -0.210155
# 1                 0.680915  ...            4.758385
# 2                 1.293731  ...           -0.210155
# 3                 0.204281  ...           -0.210155
# 4                -0.544715  ...           -0.210155
#
#    Zipcode_Group_Zipcode_Group1  Zipcode_Group_Zipcode_Group2  \
# 0                     -0.350481                     -0.482158
# 1                     -0.350481                      2.074011
# 2                     -0.350481                      2.074011
# 3                     -0.350481                     -0.482158
# 4                     -0.350481                     -0.482158
#
#    Zipcode_Group_Zipcode_Group3  Zipcode_Group_Zipcode_Group4  \
# 0                     -0.419600                     -0.479094
# 1                     -0.419600                     -0.479094
# 2                     -0.419600                     -0.479094
# 3                      2.383223                     -0.479094
# 4                     -0.419600                      2.087275
#
#    Zipcode_Group_Zipcode_Group5  Zipcode_Group_Zipcode_Group6  \
# 0                     -0.214086                     -0.287712
# 1                     -0.214086                     -0.287712
# 2                     -0.214086                     -0.287712
# 3                     -0.214086                     -0.287712
# 4                     -0.214086                     -0.287712
#
#    Zipcode_Group_Zipcode_Group7  Zipcode_Group_Zipcode_Group8  \
# 0                     -0.112274                      -0.16885
# 1                     -0.112274                      -0.16885
# 2                     -0.112274                      -0.16885
# 3                     -0.112274                      -0.16885
# 4                     -0.112274                      -0.16885
#
#    Zipcode_Group_Zipcode_Group9
# 0                     -0.048158
# 1                     -0.048158
# 2                     -0.048158
# 3                     -0.048158
# 4                     -0.048158
#
# [5 rows x 30 columns]

# %% [markdown]
# # CHECKING AND REMOVING MULTICOLLINEARITY

# %%
X.corr()
# Out:
#                                            No of Bedrooms  No of Bathrooms  \
# No of Bedrooms                                   1.000000         0.515813
# No of Bathrooms                                  0.515813         1.000000
# Flat Area (in Sqft)                              0.576628         0.754568
# Lot Area (in Sqft)                               0.031692         0.087732
# No of Floors                                     0.175536         0.500776
# No of Times Visited                              0.079575         0.187791
# Overall Grade                                    0.349223         0.635638
# Area of the House from Basement (in Sqft)        0.477549         0.685088
# Basement Area (in Sqft)                          0.303294         0.283798
# Age of House (in Years)                         -0.154113        -0.505954
# Latitude                                        -0.008708         0.024570
# Longitude                                        0.129569         0.223171
# Living Area after Renovation (in Sqft)           0.391771         0.568568
# Lot Area after Renovation (in Sqft)              0.029264         0.087226
# Years Since Renovation                          -0.007198         0.003551
# Condition_of_the_House_Excellent                 0.028148        -0.034281
# Condition_of_the_House_Fair                      0.004778         0.190440
# Condition_of_the_House_Good                     -0.008847        -0.166037
# Condition_of_the_House_Okay                     -0.051957        -0.077419
# Waterfront_View_Yes                             -0.006578         0.063761
# Ever_Renovated_Yes                               0.018573         0.050282
# Zipcode_Group_Zipcode_Group1                    -0.010603        -0.032810
# Zipcode_Group_Zipcode_Group2                    -0.039342        -0.081460
# Zipcode_Group_Zipcode_Group3                    -0.074129        -0.034459
# Zipcode_Group_Zipcode_Group4                     0.024433         0.084054
# Zipcode_Group_Zipcode_Group5                     0.019420         0.052804
# Zipcode_Group_Zipcode_Group6                     0.090177         0.123256
# Zipcode_Group_Zipcode_Group7                     0.016725         0.037746
# Zipcode_Group_Zipcode_Group8                     0.102736         0.110012
# Zipcode_Group_Zipcode_Group9                     0.035694         0.067871
#
#                                            Flat Area (in Sqft)  \
# No of Bedrooms                                        0.576628
# No of Bathrooms                                       0.754568
# Flat Area (in Sqft)                                   1.000000
# Lot Area (in Sqft)                                    0.172721
# No of Floors                                          0.354142
# No of Times Visited                                   0.284678
# Overall Grade                                         0.705725
# Area of the House from Basement (in Sqft)             0.876226
# Basement Area (in Sqft)                               0.435142
# Age of House (in Years)                              -0.318146
# Latitude                                              0.052538
# Longitude                                             0.240091
# Living Area after Renovation (in Sqft)                0.756185
# Lot Area after Renovation (in Sqft)                   0.183223
# Years Since Renovation                                0.023503
# Condition_of_the_House_Excellent                     -0.018182
# Condition_of_the_House_Fair                           0.102627
# Condition_of_the_House_Good                          -0.083995
# Condition_of_the_House_Okay                          -0.065334
# Waterfront_View_Yes                                   0.103841
# Ever_Renovated_Yes                                    0.055111
# Zipcode_Group_Zipcode_Group1                         -0.058817
# Zipcode_Group_Zipcode_Group2                         -0.063005
# Zipcode_Group_Zipcode_Group3                         -0.078761
# Zipcode_Group_Zipcode_Group4                          0.086139
# Zipcode_Group_Zipcode_Group5                          0.075978
# Zipcode_Group_Zipcode_Group6                          0.160045
# Zipcode_Group_Zipcode_Group7                          0.051211
# Zipcode_Group_Zipcode_Group8                          0.169576
# Zipcode_Group_Zipcode_Group9                          0.090253
#
#                                            Lot Area (in Sqft)  No of Floors  \
# No of Bedrooms                                       0.031692      0.175536
# No of Bathrooms                                      0.087732      0.500776
# Flat Area (in Sqft)                                  0.172721      0.354142
# Lot Area (in Sqft)                                   1.000000     -0.005162
# No of Floors                                        -0.005162      1.000000
# No of Times Visited                                  0.074668      0.029504
# Overall Grade                                        0.102314      0.461368
# Area of the House from Basement (in Sqft)            0.183492      0.524031
# Basement Area (in Sqft)                              0.015252     -0.245572
# Age of House (in Years)                             -0.053119     -0.489244
# Latitude                                            -0.085719      0.049692
# Longitude                                            0.229449      0.125620
# Living Area after Renovation (in Sqft)               0.144507      0.280106
# Lot Area after Renovation (in Sqft)                  0.718527     -0.011204
# Years Since Renovation                               0.013835     -0.000901
# Condition_of_the_House_Excellent                    -0.014503     -0.120524
# Condition_of_the_House_Fair                         -0.011334      0.317934
# Condition_of_the_House_Good                          0.013033     -0.257680
# Condition_of_the_House_Okay                          0.037619     -0.055951
# Waterfront_View_Yes                                  0.021605      0.023719
# Ever_Renovated_Yes                                   0.007736      0.006297
# Zipcode_Group_Zipcode_Group1                         0.023684     -0.003385
# Zipcode_Group_Zipcode_Group2                         0.052103     -0.067904
# Zipcode_Group_Zipcode_Group3                        -0.041112      0.079211
# Zipcode_Group_Zipcode_Group4                        -0.012050      0.071786
# Zipcode_Group_Zipcode_Group5                         0.015320      0.009203
# Zipcode_Group_Zipcode_Group6                        -0.023270      0.069857
# Zipcode_Group_Zipcode_Group7                        -0.027419      0.064981
# Zipcode_Group_Zipcode_Group8                        -0.007025     -0.008633
# Zipcode_Group_Zipcode_Group9                         0.002671      0.005868
#
#                                            No of Times Visited  Overall Grade  \
# No of Bedrooms                                        0.079575       0.349223
# No of Bathrooms                                       0.187791       0.635638
# Flat Area (in Sqft)                                   0.284678       0.705725
# Lot Area (in Sqft)                                    0.074668       0.102314
# No of Floors                                          0.029504       0.461368
# No of Times Visited                                   1.000000       0.223661
# Overall Grade                                         0.223661       1.000000
# Area of the House from Basement (in Sqft)             0.167812       0.705153
# Basement Area (in Sqft)                               0.276974       0.145232
# Age of House (in Years)                               0.053395      -0.456711
# Latitude                                              0.006162       0.111226
# Longitude                                            -0.078453       0.201736
# Living Area after Renovation (in Sqft)                0.280452       0.681362
# Lot Area after Renovation (in Sqft)                   0.072561       0.107581
# Years Since Renovation                                0.093546      -0.024388
# Condition_of_the_House_Excellent                      0.034392      -0.082628
# Condition_of_the_House_Fair                          -0.037127       0.197510
# Condition_of_the_House_Good                           0.022690      -0.140113
# Condition_of_the_House_Okay                          -0.018557      -0.090561
# Waterfront_View_Yes                                   0.401856       0.070332
# Ever_Renovated_Yes                                    0.104051       0.010010
# Zipcode_Group_Zipcode_Group1                         -0.065000      -0.075495
# Zipcode_Group_Zipcode_Group2                          0.004754      -0.121379
# Zipcode_Group_Zipcode_Group3                          0.005905      -0.047869
# Zipcode_Group_Zipcode_Group4                          0.003509       0.151245
# Zipcode_Group_Zipcode_Group5                          0.024801       0.095613
# Zipcode_Group_Zipcode_Group6                          0.068144       0.200548
# Zipcode_Group_Zipcode_Group7                         -0.012548       0.077126
# Zipcode_Group_Zipcode_Group8                          0.065335       0.156952
# Zipcode_Group_Zipcode_Group9                          0.012923       0.048638
#
#                                            Area of the House from Basement (in Sqft)  \
# No of Bedrooms                                                              0.477549
# No of Bathrooms                                                             0.685088
# Flat Area (in Sqft)                                                         0.876226
# Lot Area (in Sqft)                                                          0.183492
# No of Floors                                                                0.524031
# No of Times Visited                                                         0.167812
# Overall Grade                                                               0.705153
# Area of the House from Basement (in Sqft)                                   1.000000
# Basement Area (in Sqft)                                                    -0.051825
# Age of House (in Years)                                                    -0.423848
# Latitude                                                                   -0.000819
# Longitude                                                                   0.343793
# Living Area after Renovation (in Sqft)                                      0.731996
# Lot Area after Renovation (in Sqft)                                         0.194106
# Years Since Renovation                                                      0.010491
# Condition_of_the_House_Excellent                                           -0.088424
# Condition_of_the_House_Fair                                                 0.194517
# Condition_of_the_House_Good                                                -0.142458
# Condition_of_the_House_Okay                                                -0.058931
# Waterfront_View_Yes                                                         0.072099
# Ever_Renovated_Yes                                                          0.023202
# Zipcode_Group_Zipcode_Group1                                               -0.028348
# Zipcode_Group_Zipcode_Group2                                               -0.052418
# Zipcode_Group_Zipcode_Group3                                               -0.090628
# Zipcode_Group_Zipcode_Group4                                                0.086640
# Zipcode_Group_Zipcode_Group5                                                0.062267
# Zipcode_Group_Zipcode_Group6                                                0.129310
# Zipcode_Group_Zipcode_Group7                                                0.029477
# Zipcode_Group_Zipcode_Group8                                                0.134021
# Zipcode_Group_Zipcode_Group9                                                0.087398
#
#                                            Basement Area (in Sqft)  \
# No of Bedrooms                                            0.303294
# No of Bathrooms                                           0.283798
# Flat Area (in Sqft)                                       0.435142
# Lot Area (in Sqft)                                        0.015252
# No of Floors                                             -0.245572
# No of Times Visited                                       0.276974
# Overall Grade                                             0.145232
# Area of the House from Basement (in Sqft)                -0.051825
# Basement Area (in Sqft)                                   1.000000
# Age of House (in Years)                                   0.133072
# Latitude                                                  0.110451
# Longitude                                                -0.144822
# Living Area after Renovation (in Sqft)                    0.200302
# Lot Area after Renovation (in Sqft)                       0.017263
# Years Since Renovation                                    0.029158
# Condition_of_the_House_Excellent                          0.127876
# Condition_of_the_House_Fair                              -0.151347
# Condition_of_the_House_Good                               0.092539
# Condition_of_the_House_Okay                              -0.025312
# Waterfront_View_Yes                                       0.080595
# Ever_Renovated_Yes                                        0.070969
# Zipcode_Group_Zipcode_Group1                             -0.069149
# Zipcode_Group_Zipcode_Group2                             -0.032302
# Zipcode_Group_Zipcode_Group3                              0.006247
# Zipcode_Group_Zipcode_Group4                              0.016422
# Zipcode_Group_Zipcode_Group5                              0.040662
# Zipcode_Group_Zipcode_Group6                              0.090206
# Zipcode_Group_Zipcode_Group7                              0.051128
# Zipcode_Group_Zipcode_Group8                              0.101159
# Zipcode_Group_Zipcode_Group9                              0.023775
#
#                                            Age of House (in Years)  ...  \
# No of Bedrooms                                           -0.154113  ...
# No of Bathrooms                                          -0.505954  ...
# Flat Area (in Sqft)                                      -0.318146  ...
# Lot Area (in Sqft)                                       -0.053119  ...
# No of Floors                                             -0.489244  ...
# No of Times Visited                                       0.053395  ...
# Overall Grade                                            -0.456711  ...
# Area of the House from Basement (in Sqft)                -0.423848  ...
# Basement Area (in Sqft)                                   0.133072  ...
# Age of House (in Years)                                   1.000000  ...
# Latitude                                                  0.148083  ...
# Longitude                                                -0.409515  ...
# Living Area after Renovation (in Sqft)                   -0.326307  ...
# Lot Area after Renovation (in Sqft)                      -0.071016  ...
# Years Since Renovation                                    0.203375  ...
# Condition_of_the_House_Excellent                          0.244330  ...
# Condition_of_the_House_Fair                              -0.391693  ...
# Condition_of_the_House_Good                               0.257392  ...
# Condition_of_the_House_Okay                               0.067269  ...
# Waterfront_View_Yes                                       0.026149  ...
# Ever_Renovated_Yes                                        0.225182  ...
# Zipcode_Group_Zipcode_Group1                             -0.070111  ...
# Zipcode_Group_Zipcode_Group2                              0.022094  ...
# Zipcode_Group_Zipcode_Group3                              0.095882  ...
# Zipcode_Group_Zipcode_Group4                             -0.056974  ...
# Zipcode_Group_Zipcode_Group5                             -0.009965  ...
# Zipcode_Group_Zipcode_Group6                              0.025718  ...
# Zipcode_Group_Zipcode_Group7                              0.101486  ...
# Zipcode_Group_Zipcode_Group8                             -0.002705  ...
# Zipcode_Group_Zipcode_Group9                             -0.002492  ...
#
#                                            Ever_Renovated_Yes  \
# No of Bedrooms                                       0.018573
# No of Bathrooms                                      0.050282
# Flat Area (in Sqft)                                  0.055111
# Lot Area (in Sqft)                                   0.007736
# No of Floors                                         0.006297
# No of Times Visited                                  0.104051
# Overall Grade                                        0.010010
# Area of the House from Basement (in Sqft)            0.023202
# Basement Area (in Sqft)                              0.070969
# Age of House (in Years)                              0.225182
# Latitude                                             0.029357
# Longitude                                           -0.068416
# Living Area after Renovation (in Sqft)              -0.002756
# Lot Area after Renovation (in Sqft)                  0.007910
# Years Since Renovation                               0.796854
# Condition_of_the_House_Excellent                    -0.029839
# Condition_of_the_House_Fair                          0.068731
# Condition_of_the_House_Good                         -0.054416
# Condition_of_the_House_Okay                         -0.008474
# Waterfront_View_Yes                                  0.093291
# Ever_Renovated_Yes                                   1.000000
# Zipcode_Group_Zipcode_Group1                        -0.014726
# Zipcode_Group_Zipcode_Group2                         0.000938
# Zipcode_Group_Zipcode_Group3                         0.005909
# Zipcode_Group_Zipcode_Group4                        -0.004500
# Zipcode_Group_Zipcode_Group5                         0.011170
# Zipcode_Group_Zipcode_Group6                         0.007896
# Zipcode_Group_Zipcode_Group7                         0.038617
# Zipcode_Group_Zipcode_Group8                         0.056952
# Zipcode_Group_Zipcode_Group9                         0.037735
#
#                                            Zipcode_Group_Zipcode_Group1  \
# No of Bedrooms                                                -0.010603
# No of Bathrooms                                               -0.032810
# Flat Area (in Sqft)                                           -0.058817
# Lot Area (in Sqft)                                             0.023684
# No of Floors                                                  -0.003385
# No of Times Visited                                           -0.065000
# Overall Grade                                                 -0.075495
# Area of the House from Basement (in Sqft)                     -0.028348
# Basement Area (in Sqft)                                       -0.069149
# Age of House (in Years)                                       -0.070111
# Latitude                                                      -0.199187
# Longitude                                                      0.032913
# Living Area after Renovation (in Sqft)                        -0.064207
# Lot Area after Renovation (in Sqft)                            0.028096
# Years Since Renovation                                        -0.006039
# Condition_of_the_House_Excellent                              -0.017665
# Condition_of_the_House_Fair                                    0.021545
# Condition_of_the_House_Good                                   -0.013193
# Condition_of_the_House_Okay                                    0.005311
# Waterfront_View_Yes                                           -0.016847
# Ever_Renovated_Yes                                            -0.014726
# Zipcode_Group_Zipcode_Group1                                   1.000000
# Zipcode_Group_Zipcode_Group2                                  -0.168987
# Zipcode_Group_Zipcode_Group3                                  -0.147062
# Zipcode_Group_Zipcode_Group4                                  -0.167913
# Zipcode_Group_Zipcode_Group5                                  -0.075033
# Zipcode_Group_Zipcode_Group6                                  -0.100838
# Zipcode_Group_Zipcode_Group7                                  -0.039350
# Zipcode_Group_Zipcode_Group8                                  -0.059179
# Zipcode_Group_Zipcode_Group9                                  -0.016879
#
#                                            Zipcode_Group_Zipcode_Group2  \
# No of Bedrooms                                                -0.039342
# No of Bathrooms                                               -0.081460
# Flat Area (in Sqft)                                           -0.063005
# Lot Area (in Sqft)                                             0.052103
# No of Floors                                                  -0.067904
# No of Times Visited                                            0.004754
# Overall Grade                                                 -0.121379
# Area of the House from Basement (in Sqft)                     -0.052418
# Basement Area (in Sqft)                                       -0.032302
# Age of House (in Years)                                        0.022094
# Latitude                                                       0.120400
# Longitude                                                      0.024489
# Living Area after Renovation (in Sqft)                        -0.082698
# Lot Area after Renovation (in Sqft)                            0.065514
# Years Since Renovation                                         0.004376
# Condition_of_the_House_Excellent                               0.020271
# Condition_of_the_House_Fair                                    0.007924
# Condition_of_the_House_Good                                   -0.026880
# Condition_of_the_House_Okay                                    0.030027
# Waterfront_View_Yes                                            0.039995
# Ever_Renovated_Yes                                             0.000938
# Zipcode_Group_Zipcode_Group1                                  -0.168987
# Zipcode_Group_Zipcode_Group2                                   1.000000
# Zipcode_Group_Zipcode_Group3                                  -0.202313
# Zipcode_Group_Zipcode_Group4                                  -0.230999
# Zipcode_Group_Zipcode_Group5                                  -0.103223
# Zipcode_Group_Zipcode_Group6                                  -0.138722
# Zipcode_Group_Zipcode_Group7                                  -0.054134
# Zipcode_Group_Zipcode_Group8                                  -0.081412
# Zipcode_Group_Zipcode_Group9                                  -0.023220
#
#                                            Zipcode_Group_Zipcode_Group3  \
# No of Bedrooms                                                -0.074129
# No of Bathrooms                                               -0.034459
# Flat Area (in Sqft)                                           -0.078761
# Lot Area (in Sqft)                                            -0.041112
# No of Floors                                                   0.079211
# No of Times Visited                                            0.005905
# Overall Grade                                                 -0.047869
# Area of the House from Basement (in Sqft)                     -0.090628
# Basement Area (in Sqft)                                        0.006247
# Age of House (in Years)                                        0.095882
# Latitude                                                       0.283760
# Longitude                                                     -0.117243
# Living Area after Renovation (in Sqft)                        -0.108365
# Lot Area after Renovation (in Sqft)                           -0.056258
# Years Since Renovation                                         0.004296
# Condition_of_the_House_Excellent                               0.015100
# Condition_of_the_House_Fair                                    0.018732
# Condition_of_the_House_Good                                   -0.027416
# Condition_of_the_House_Okay                                   -0.011312
# Waterfront_View_Yes                                           -0.017093
# Ever_Renovated_Yes                                             0.005909
# Zipcode_Group_Zipcode_Group1                                  -0.147062
# Zipcode_Group_Zipcode_Group2                                  -0.202313
# Zipcode_Group_Zipcode_Group3                                   1.000000
# Zipcode_Group_Zipcode_Group4                                  -0.201028
# Zipcode_Group_Zipcode_Group5                                  -0.089831
# Zipcode_Group_Zipcode_Group6                                  -0.120724
# Zipcode_Group_Zipcode_Group7                                  -0.047110
# Zipcode_Group_Zipcode_Group8                                  -0.070849
# Zipcode_Group_Zipcode_Group9                                  -0.020207
#
#                                            Zipcode_Group_Zipcode_Group4  \
# No of Bedrooms                                                 0.024433
# No of Bathrooms                                                0.084054
# Flat Area (in Sqft)                                            0.086139
# Lot Area (in Sqft)                                            -0.012050
# No of Floors                                                   0.071786
# No of Times Visited                                            0.003509
# Overall Grade                                                  0.151245
# Area of the House from Basement (in Sqft)                      0.086640
# Basement Area (in Sqft)                                        0.016422
# Age of House (in Years)                                       -0.056974
# Latitude                                                       0.249304
# Longitude                                                      0.174136
# Living Area after Renovation (in Sqft)                         0.108457
# Lot Area after Renovation (in Sqft)                           -0.006145
# Years Since Renovation                                        -0.008853
# Condition_of_the_House_Excellent                              -0.026260
# Condition_of_the_House_Fair                                    0.046346
# Condition_of_the_House_Good                                   -0.030755
# Condition_of_the_House_Okay                                   -0.018857
# Waterfront_View_Yes                                           -0.010197
# Ever_Renovated_Yes                                            -0.004500
# Zipcode_Group_Zipcode_Group1                                  -0.167913
# Zipcode_Group_Zipcode_Group2                                  -0.230999
# Zipcode_Group_Zipcode_Group3                                  -0.201028
# Zipcode_Group_Zipcode_Group4                                   1.000000
# Zipcode_Group_Zipcode_Group5                                  -0.102567
# Zipcode_Group_Zipcode_Group6                                  -0.137841
# Zipcode_Group_Zipcode_Group7                                  -0.053790
# Zipcode_Group_Zipcode_Group8                                  -0.080895
# Zipcode_Group_Zipcode_Group9                                  -0.023072
#
#                                            Zipcode_Group_Zipcode_Group5  \
# No of Bedrooms                                                 0.019420
# No of Bathrooms                                                0.052804
# Flat Area (in Sqft)                                            0.075978
# Lot Area (in Sqft)                                             0.015320
# No of Floors                                                   0.009203
# No of Times Visited                                            0.024801
# Overall Grade                                                  0.095613
# Area of the House from Basement (in Sqft)                      0.062267
# Basement Area (in Sqft)                                        0.040662
# Age of House (in Years)                                       -0.009965
# Latitude                                                       0.190199
# Longitude                                                     -0.027225
# Living Area after Renovation (in Sqft)                         0.084243
# Lot Area after Renovation (in Sqft)                            0.023794
# Years Since Renovation                                         0.009024
# Condition_of_the_House_Excellent                               0.012134
# Condition_of_the_House_Fair                                   -0.014101
# Condition_of_the_House_Good                                    0.009844
# Condition_of_the_House_Okay                                   -0.009000
# Waterfront_View_Yes                                           -0.005600
# Ever_Renovated_Yes                                             0.011170
# Zipcode_Group_Zipcode_Group1                                  -0.075033
# Zipcode_Group_Zipcode_Group2                                  -0.103223
# Zipcode_Group_Zipcode_Group3                                  -0.089831
# Zipcode_Group_Zipcode_Group4                                  -0.102567
# Zipcode_Group_Zipcode_Group5                                   1.000000
# Zipcode_Group_Zipcode_Group6                                  -0.061595
# Zipcode_Group_Zipcode_Group7                                  -0.024036
# Zipcode_Group_Zipcode_Group8                                  -0.036148
# Zipcode_Group_Zipcode_Group9                                  -0.010310
#
#                                            Zipcode_Group_Zipcode_Group6  \
# No of Bedrooms                                                 0.090177
# No of Bathrooms                                                0.123256
# Flat Area (in Sqft)                                            0.160045
# Lot Area (in Sqft)                                            -0.023270
# No of Floors                                                   0.069857
# No of Times Visited                                            0.068144
# Overall Grade                                                  0.200548
# Area of the House from Basement (in Sqft)                      0.129310
# Basement Area (in Sqft)                                        0.090206
# Age of House (in Years)                                        0.025718
# Latitude                                                       0.090785
# Longitude                                                      0.045875
# Living Area after Renovation (in Sqft)                         0.210982
# Lot Area after Renovation (in Sqft)                           -0.025459
# Years Since Renovation                                        -0.003087
# Condition_of_the_House_Excellent                               0.029723
# Condition_of_the_House_Fair                                   -0.030814
# Condition_of_the_House_Good                                    0.018961
# Condition_of_the_House_Okay                                   -0.017932
# Waterfront_View_Yes                                            0.009136
# Ever_Renovated_Yes                                             0.007896
# Zipcode_Group_Zipcode_Group1                                  -0.100838
# Zipcode_Group_Zipcode_Group2                                  -0.138722
# Zipcode_Group_Zipcode_Group3                                  -0.120724
# Zipcode_Group_Zipcode_Group4                                  -0.137841
# Zipcode_Group_Zipcode_Group5                                  -0.061595
# Zipcode_Group_Zipcode_Group6                                   1.000000
# Zipcode_Group_Zipcode_Group7                                  -0.032303
# Zipcode_Group_Zipcode_Group8                                  -0.048580
# Zipcode_Group_Zipcode_Group9                                  -0.013856
#
#                                            Zipcode_Group_Zipcode_Group7  \
# No of Bedrooms                                                 0.016725
# No of Bathrooms                                                0.037746
# Flat Area (in Sqft)                                            0.051211
# Lot Area (in Sqft)                                            -0.027419
# No of Floors                                                   0.064981
# No of Times Visited                                           -0.012548
# Overall Grade                                                  0.077126
# Area of the House from Basement (in Sqft)                      0.029477
# Basement Area (in Sqft)                                        0.051128
# Age of House (in Years)                                        0.101486
# Latitude                                                       0.056373
# Longitude                                                     -0.066961
# Living Area after Renovation (in Sqft)                         0.048081
# Lot Area after Renovation (in Sqft)                           -0.032366
# Years Since Renovation                                         0.019224
# Condition_of_the_House_Excellent                               0.029176
# Condition_of_the_House_Fair                                   -0.010169
# Condition_of_the_House_Good                                   -0.007285
# Condition_of_the_House_Okay                                   -0.000663
# Waterfront_View_Yes                                           -0.009788
# Ever_Renovated_Yes                                             0.038617
# Zipcode_Group_Zipcode_Group1                                  -0.039350
# Zipcode_Group_Zipcode_Group2                                  -0.054134
# Zipcode_Group_Zipcode_Group3                                  -0.047110
# Zipcode_Group_Zipcode_Group4                                  -0.053790
# Zipcode_Group_Zipcode_Group5                                  -0.024036
# Zipcode_Group_Zipcode_Group6                                  -0.032303
# Zipcode_Group_Zipcode_Group7                                   1.000000
# Zipcode_Group_Zipcode_Group8                                  -0.018957
# Zipcode_Group_Zipcode_Group9                                  -0.005407
#
#                                            Zipcode_Group_Zipcode_Group8  \
# No of Bedrooms                                                 0.102736
# No of Bathrooms                                                0.110012
# Flat Area (in Sqft)                                            0.169576
# Lot Area (in Sqft)                                            -0.007025
# No of Floors                                                  -0.008633
# No of Times Visited                                            0.065335
# Overall Grade                                                  0.156952
# Area of the House from Basement (in Sqft)                      0.134021
# Basement Area (in Sqft)                                        0.101159
# Age of House (in Years)                                       -0.002705
# Latitude                                                       0.036085
# Longitude                                                     -0.001103
# Living Area after Renovation (in Sqft)                         0.195508
# Lot Area after Renovation (in Sqft)                            0.000207
# Years Since Renovation                                         0.038785
# Condition_of_the_House_Excellent                               0.013449
# Condition_of_the_House_Fair                                   -0.069614
# Condition_of_the_House_Good                                    0.068277
# Condition_of_the_House_Okay                                   -0.005608
# Waterfront_View_Yes                                            0.027633
# Ever_Renovated_Yes                                             0.056952
# Zipcode_Group_Zipcode_Group1                                  -0.059179
# Zipcode_Group_Zipcode_Group2                                  -0.081412
# Zipcode_Group_Zipcode_Group3                                  -0.070849
# Zipcode_Group_Zipcode_Group4                                  -0.080895
# Zipcode_Group_Zipcode_Group5                                  -0.036148
# Zipcode_Group_Zipcode_Group6                                  -0.048580
# Zipcode_Group_Zipcode_Group7                                  -0.018957
# Zipcode_Group_Zipcode_Group8                                   1.000000
# Zipcode_Group_Zipcode_Group9                                  -0.008132
#
#                                            Zipcode_Group_Zipcode_Group9
# No of Bedrooms                                                 0.035694
# No of Bathrooms                                                0.067871
# Flat Area (in Sqft)                                            0.090253
# Lot Area (in Sqft)                                             0.002671
# No of Floors                                                   0.005868
# No of Times Visited                                            0.012923
# Overall Grade                                                  0.048638
# Area of the House from Basement (in Sqft)                      0.087398
# Basement Area (in Sqft)                                        0.023775
# Age of House (in Years)                                       -0.002492
# Latitude                                                       0.022867
# Longitude                                                     -0.006725
# Living Area after Renovation (in Sqft)                         0.080495
# Lot Area after Renovation (in Sqft)                            0.007974
# Years Since Renovation                                         0.034990
# Condition_of_the_House_Excellent                              -0.006924
# Condition_of_the_House_Fair                                   -0.008999
# Condition_of_the_House_Good                                    0.015016
# Condition_of_the_House_Okay                                   -0.004314
# Waterfront_View_Yes                                            0.006933
# Ever_Renovated_Yes                                             0.037735
# Zipcode_Group_Zipcode_Group1                                  -0.016879
# Zipcode_Group_Zipcode_Group2                                  -0.023220
# Zipcode_Group_Zipcode_Group3                                  -0.020207
# Zipcode_Group_Zipcode_Group4                                  -0.023072
# Zipcode_Group_Zipcode_Group5                                  -0.010310
# Zipcode_Group_Zipcode_Group6                                  -0.013856
# Zipcode_Group_Zipcode_Group7                                  -0.005407
# Zipcode_Group_Zipcode_Group8                                  -0.008132
# Zipcode_Group_Zipcode_Group9                                   1.000000
#
# [30 rows x 30 columns]

# %%
# pair of independent variables corr >0.5
k=X.corr()
# List Compression
z=[[str(i),str(j)] for i in k.columns for j in k.columns if (k.loc[i,j] >abs(0.5))&(i!=j)]
z,len(z)
# Out:
# ([['No of Bedrooms', 'No of Bathrooms'],
#   ['No of Bedrooms', 'Flat Area (in Sqft)'],
#   ['No of Bathrooms', 'No of Bedrooms'],
#   ['No of Bathrooms', 'Flat Area (in Sqft)'],
#   ['No of Bathrooms', 'No of Floors'],
#   ['No of Bathrooms', 'Overall Grade'],
#   ['No of Bathrooms', 'Area of the House from Basement (in Sqft)'],
#   ['No of Bathrooms', 'Living Area after Renovation (in Sqft)'],
#   ['Flat Area (in Sqft)', 'No of Bedrooms'],
#   ['Flat Area (in Sqft)', 'No of Bathrooms'],
#   ['Flat Area (in Sqft)', 'Overall Grade'],
#   ['Flat Area (in Sqft)', 'Area of the House from Basement (in Sqft)'],
#   ['Flat Area (in Sqft)', 'Living Area after Renovation (in Sqft)'],
#   ['Lot Area (in Sqft)', 'Lot Area after Renovation (in Sqft)'],
#   ['No of Floors', 'No of Bathrooms'],
#   ['No of Floors', 'Area of the House from Basement (in Sqft)'],
#   ['Overall Grade', 'No of Bathrooms'],
#   ['Overall Grade', 'Flat Area (in Sqft)'],
#   ['Overall Grade', 'Area of the House from Basement (in Sqft)'],
#   ['Overall Grade', 'Living Area after Renovation (in Sqft)'],
#   ['Area of the House from Basement (in Sqft)', 'No of Bathrooms'],
#   ['Area of the House from Basement (in Sqft)', 'Flat Area (in Sqft)'],
#   ['Area of the House from Basement (in Sqft)', 'No of Floors'],
#   ['Area of the House from Basement (in Sqft)', 'Overall Grade'],
#   ['Area of the House from Basement (in Sqft)',
#    'Living Area after Renovation (in Sqft)'],
#   ['Living Area after Renovation (in Sqft)', 'No of Bathrooms'],
#   ['Living Area after Renovation (in Sqft)', 'Flat Area (in Sqft)'],
#   ['Living Area after Renovation (in Sqft)', 'Overall Grade'],
#   ['Living Area after Renovation (in Sqft)',
#    'Area of the House from Basement (in Sqft)'],
#   ['Lot Area after Renovation (in Sqft)', 'Lot Area (in Sqft)'],
#   ['Years Since Renovation', 'Ever_Renovated_Yes'],
#   ['Ever_Renovated_Yes', 'Years Since Renovation']],
#  32)

# %% [markdown]
# # CALCULATING VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif_data=X
# calc vif for every column by list compression
VIF=pd.Series([variance_inflation_factor(vif_data.values,i) for i in range(vif_data.shape[1])],index=vif_data.columns)
VIF
# Out:
# No of Bedrooms                                  1.639470
# No of Bathrooms                                 3.374992
# Flat Area (in Sqft)                          1481.681648
# Lot Area (in Sqft)                              2.108079
# No of Floors                                    2.127787
# No of Times Visited                             1.432385
# Overall Grade                                   2.967448
# Area of the House from Basement (in Sqft)    1205.549115
# Basement Area (in Sqft)                       345.465009
# Age of House (in Years)                         2.629539
# Latitude                                        2.471442
# Longitude                                       1.672691
# Living Area after Renovation (in Sqft)          3.068139
# Lot Area after Renovation (in Sqft)             2.144347
# Years Since Renovation                          2.788098
# Condition_of_the_House_Excellent               53.578111
# Condition_of_the_House_Fair                   166.129930
# Condition_of_the_House_Good                   141.324536
# Condition_of_the_House_Okay                     6.703057
# Waterfront_View_Yes                             1.208439
# Ever_Renovated_Yes                              2.955790
# Zipcode_Group_Zipcode_Group1                    1.538226
# Zipcode_Group_Zipcode_Group2                    2.570591
# Zipcode_Group_Zipcode_Group3                    2.818579
# Zipcode_Group_Zipcode_Group4                    3.193051
# Zipcode_Group_Zipcode_Group5                    1.728330
# Zipcode_Group_Zipcode_Group6                    2.015017
# Zipcode_Group_Zipcode_Group7                    1.233754
# Zipcode_Group_Zipcode_Group8                    1.389653
# Zipcode_Group_Zipcode_Group9                    1.048579
# dtype: float64

# %%
VIF[VIF == VIF.max()].index[0]
# Out:
# 'Flat Area (in Sqft)'

# %%
def MC_remover(data):
    vif=pd.Series([variance_inflation_factor(data.values,i) for i in range(data.shape[1])],index=data.columns)
    if vif.max() > 5:
        print(vif[vif == vif.max()].index[0],'has been removed.')
        data=data.drop(columns=[vif[vif == vif.max()].index[0]])
        return data
    else:
        print('No Multicollinearity is left.')
        return data

# %%
for i in range(7):
    vif_data=MC_remover(vif_data)

vif_data.head()
# Out:
# Flat Area (in Sqft) has been removed.
# Condition_of_the_House_Fair has been removed.
# No Multicollinearity is left.
# No Multicollinearity is left.
# No Multicollinearity is left.
# No Multicollinearity is left.
# No Multicollinearity is left.
#    No of Bedrooms  No of Bathrooms  Lot Area (in Sqft)  No of Floors  \
# 0       -0.398724        -1.447526           -0.228291     -0.915389
# 1       -0.398724         0.175684           -0.189858      0.936817
# 2       -1.474115        -1.447526           -0.123276     -0.915389
# 3        0.676667         1.149611           -0.243983     -0.915389
# 4       -0.398724        -0.148958           -0.169628     -0.915389
#
#    No of Times Visited  Overall Grade  \
# 0             -0.30579      -0.563993
# 1             -0.30579      -0.563993
# 2             -0.30579      -1.468566
# 3             -0.30579      -0.563993
# 4             -0.30579       0.340581
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  \
# 0                                  -0.734722                -0.658697
# 1                                   0.460990                 0.245134
# 2                                  -1.229916                -0.658697
# 3                                  -0.891735                 1.397518
# 4                                  -0.130827                -0.658697
#
#    Age of House (in Years)  Latitude  ...  Ever_Renovated_Yes  \
# 0                 0.544734 -0.352576  ...           -0.210155
# 1                 0.680915  1.161645  ...            4.758385
# 2                 1.293731  1.283619  ...           -0.210155
# 3                 0.204281 -0.283288  ...           -0.210155
# 4                -0.544715  0.409587  ...           -0.210155
#
#    Zipcode_Group_Zipcode_Group1  Zipcode_Group_Zipcode_Group2  \
# 0                     -0.350481                     -0.482158
# 1                     -0.350481                      2.074011
# 2                     -0.350481                      2.074011
# 3                     -0.350481                     -0.482158
# 4                     -0.350481                     -0.482158
#
#    Zipcode_Group_Zipcode_Group3  Zipcode_Group_Zipcode_Group4  \
# 0                     -0.419600                     -0.479094
# 1                     -0.419600                     -0.479094
# 2                     -0.419600                     -0.479094
# 3                      2.383223                     -0.479094
# 4                     -0.419600                      2.087275
#
#    Zipcode_Group_Zipcode_Group5  Zipcode_Group_Zipcode_Group6  \
# 0                     -0.214086                     -0.287712
# 1                     -0.214086                     -0.287712
# 2                     -0.214086                     -0.287712
# 3                     -0.214086                     -0.287712
# 4                     -0.214086                     -0.287712
#
#    Zipcode_Group_Zipcode_Group7  Zipcode_Group_Zipcode_Group8  \
# 0                     -0.112274                      -0.16885
# 1                     -0.112274                      -0.16885
# 2                     -0.112274                      -0.16885
# 3                     -0.112274                      -0.16885
# 4                     -0.112274                      -0.16885
#
#    Zipcode_Group_Zipcode_Group9
# 0                     -0.048158
# 1                     -0.048158
# 2                     -0.048158
# 3                     -0.048158
# 4                     -0.048158
#
# [5 rows x 28 columns]

# %%
VIF=pd.Series([variance_inflation_factor(vif_data.values,i) for i in range(vif_data.shape[1])],index=vif_data.columns)
VIF,len(vif_data.columns)
# Out:
# (No of Bedrooms                               1.638990
#  No of Bathrooms                              3.373805
#  Lot Area (in Sqft)                           2.107495
#  No of Floors                                 2.127703
#  No of Times Visited                          1.432363
#  Overall Grade                                2.956967
#  Area of the House from Basement (in Sqft)    4.580042
#  Basement Area (in Sqft)                      1.974981
#  Age of House (in Years)                      2.626504
#  Latitude                                     2.471343
#  Longitude                                    1.672667
#  Living Area after Renovation (in Sqft)       3.063886
#  Lot Area after Renovation (in Sqft)          2.144068
#  Years Since Renovation                       2.788064
#  Condition_of_the_House_Excellent             1.206487
#  Condition_of_the_House_Good                  1.251488
#  Condition_of_the_House_Okay                  1.025386
#  Waterfront_View_Yes                          1.208288
#  Ever_Renovated_Yes                           2.955539
#  Zipcode_Group_Zipcode_Group1                 1.538211
#  Zipcode_Group_Zipcode_Group2                 2.570583
#  Zipcode_Group_Zipcode_Group3                 2.818509
#  Zipcode_Group_Zipcode_Group4                 3.192429
#  Zipcode_Group_Zipcode_Group5                 1.728047
#  Zipcode_Group_Zipcode_Group6                 2.014775
#  Zipcode_Group_Zipcode_Group7                 1.233626
#  Zipcode_Group_Zipcode_Group8                 1.389355
#  Zipcode_Group_Zipcode_Group9                 1.048571
#  dtype: float64,
#  28)

# %% [markdown]
# # TRAIN AND TEST TEST

# %%
x=vif_data
y=data['Sale_Price']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=101)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((15126, 28), (6483, 28), (15126,), (6483,))

# %% [markdown]
# # LINEAR REGRESSION

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
predictions=lr.predict(x_test)
lr.score(x_test,y_test)
# Out:
# 0.8461987715586199

# %% [markdown]
# # RESIDUALS

# %%
residuals=predictions-y_test
residual_table=pd.DataFrame({'residuals':residuals,
                             'predictions':predictions})
residual_table=residual_table.sort_values(by='predictions')

# %%
z=[i for i in range(int(residual_table['predictions'].max()))]
k=[0 for i in range(int(residual_table['predictions'].max()))]

# %%
plt.figure(dpi=130,figsize=(17,7))

plt.scatter(residual_table['predictions'],residual_table['residuals'],color='green',s=2)
plt.plot(z,k,color='red',linewidth=3,label='Regression Line')
plt.xlabel('Predicted Points')
plt.ylabel('Residuals')
plt.title('Residual Plot')
plt.legend()
plt.show()

# %% [markdown]
# # DISTRIBUTION OF ERRORS

# %%
plt.figure(dpi=100,figsize=(12,7))
plt.hist(residual_table['residuals'],color='red',bins=200)
plt.xlabel('Residuals')
plt.ylabel('Frequency')
plt.title('Distribution of Residuals')
plt.show()

# %% [markdown]
# # MODEL COEFFICIENTS

# %%
coefficients_table=pd.DataFrame({'column':x_train.columns,
                                 'coefficient':lr.coef_})
coefficients_table=coefficients_table.sort_values(by='coefficient')

# %%
plt.figure(dpi=120,figsize=(12,6))
plt.barh(coefficients_table['column'],coefficients_table['coefficient'])
plt.xlabel('Coeficients')
plt.ylabel('Variables')
plt.title('Normalized Coefficient Plot')
plt.show()
